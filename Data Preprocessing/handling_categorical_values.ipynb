# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('Salary_Dataset.csv')
dataset.head()
# Out:
#   country   Salary  YearsExperience Purchased
# 0   Dubai  39343.0              1.1        No
# 1  Canada  46205.0              1.3       Yes
# 2  Canada  37731.0              1.5        No
# 3  Canada  43525.0              2.0        No
# 4     USA  39891.0              2.2        No

# %%
# lets try one hot encoding
ohe = pd.get_dummies(dataset['country'])
ohe = ohe.astype(int)
ohe.head()
# Out:
#    Australia  Canada  Dubai  USA
# 0          0       0      1    0
# 1          0       1      0    0
# 2          0       1      0    0
# 3          0       1      0    0
# 4          0       0      0    1

# %%
dataset = pd.concat([dataset, ohe], axis = 1)
dataset.head()
# Out:
#   country   Salary  YearsExperience Purchased  Australia  Canada  Dubai  USA
# 0   Dubai  39343.0              1.1        No          0       0      1    0
# 1  Canada  46205.0              1.3       Yes          0       1      0    0
# 2  Canada  37731.0              1.5        No          0       1      0    0
# 3  Canada  43525.0              2.0        No          0       1      0    0
# 4     USA  39891.0              2.2        No          0       0      0    1

# %%
dataset.drop('country',axis = 1, inplace= True)
dataset.head()
# Out:
#     Salary  YearsExperience Purchased  Australia  Canada  Dubai  USA
# 0  39343.0              1.1        No          0       0      1    0
# 1  46205.0              1.3       Yes          0       1      0    0
# 2  37731.0              1.5        No          0       1      0    0
# 3  43525.0              2.0        No          0       1      0    0
# 4  39891.0              2.2        No          0       0      0    1

# %%
dataset = dataset[['Australia','Canada','Dubai','USA','Salary','YearsExperience','Purchased']]
dataset.head()
# Out:
#    Australia  Canada  Dubai  USA   Salary  YearsExperience Purchased
# 0          0       0      1    0  39343.0              1.1        No
# 1          0       1      0    0  46205.0              1.3       Yes
# 2          0       1      0    0  37731.0              1.5        No
# 3          0       1      0    0  43525.0              2.0        No
# 4          0       0      0    1  39891.0              2.2        No

# %%
# now lets try label encoding using scikitlearn
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
dataset['Purchased'] = le.fit_transform(dataset['Purchased'])

# %%
dataset
# Out:
#     Australia  Canada  Dubai  USA    Salary  YearsExperience  Purchased
# 0           0       0      1    0   39343.0              1.1          0
# 1           0       1      0    0   46205.0              1.3          1
# 2           0       1      0    0   37731.0              1.5          0
# 3           0       1      0    0   43525.0              2.0          0
# 4           0       0      0    1   39891.0              2.2          0
# 5           0       0      1    0   56642.0              2.9          0
# 6           0       1      0    0   60150.0              3.0          1
# 7           1       0      0    0   54445.0              3.2          0
# 8           0       0      1    0   64445.0              3.2          1
# 9           0       0      1    0   57189.0              3.7          0
# 10          0       0      1    0   63218.0              3.9          1
# 11          0       0      0    1   55794.0              4.0          0
# ...
